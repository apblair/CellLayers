# %%
import scanpy as sc
import numpy as np
import pandas as pd
import collections
import json, urllib

import plotly
import seaborn as sns
import scipy.io as sci
import plotly.graph_objects as go
import chart_studio.plotly as py
# Out:
# /opt/conda/lib/python3.7/site-packages/anndata/_core/anndata.py:21: FutureWarning: pandas.core.index is deprecated and will be removed in a future version.  The public classes are available in the top-level namespace.
#   from pandas.core.index import RangeIndex

# %%
import urllib.request as ur
response = ur.urlopen("https://rawgit.com/monfera/plotly-webgl-parcoords/sankey-example-01/drones.json")
data = json.loads(response.read())

# %%
sl
# Out:
# {'layout': {'title': 'Fallen from the skies: drone crashes database - Washington Post',
#   'width': 1600,
#   'height': 1000},
#  'data': [{'type': 'sankey',
#    'domain': {'x': [0, 1], 'y': [0, 1]},
#    'nodes': [{'label': 'Afghanistan', 'visible': True},
#     {'label': 'Air Force', 'visible': True},
#     {'label': 'Army', 'visible': True},
#     {'label': 'Atlantic Ocean', 'visible': True},
#     {'label': 'Classified', 'visible': True},
#     {'label': 'Djibouti', 'visible': True},
#     {'label': 'Fire Scout', 'visible': True},
#     {'label': 'Fire Scout MQ-8B', 'visible': True},
#     {'label': 'Global Hawk', 'visible': True},
#     {'label': 'Global Hawk EQ-4B', 'visible': True},
#     {'label': 'Global Hawk RQ-4A', 'visible': True},
#     {'label': 'Gray Eagle', 'visible': True},
#     {'label': 'Gray Eagle MQ-1C', 'visible': True},
#     {'label': 'Hummingbird', 'visible': True},
#     {'label': 'Hummingbird A160T Hummingbird', 'visible': True},
# ...

# %%
url = 'https://rawgit.com/monfera/plotly-webgl-parcoords/sankey-example-01/drones.json'
with urllib.request.urlopen(url) as url:
    response = url.read()
data = json.loads(response.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-953ecd60aea4> in <module>
#       2 with urllib.request.urlopen(url) as url:
#       3     response = url.read()
# ----> 4 data = json.loads(response.read())
#
# AttributeError: 'bytes' object has no attribute 'read'

# %%
class CellLayers(object):
    def __init__(self, adata):
        
        self.adata = adata

# %%
adata = sc.read('../Data/pbmc.h5ad')

# %%
# url = 'https://raw.githubusercontent.com/plotly/plotly.js/master/test/image/mocks/sankey_energy.json'
energy_data = json.loads('sankey_energy.json')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-16-023dfe60ed06> in <module>
#       1 # url = 'https://raw.githubusercontent.com/plotly/plotly.js/master/test/image/mocks/sankey_energy.json'
# ----> 2 energy_data = json.loads('sankey_energy.json')
#
# /opt/conda/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# /opt/conda/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
# ...
